# %% [markdown]
# # Guide to Animated bubble charts using Plotly

# %% [markdown]
# I used to be amazed by [Hans Rosling's Ted Talks](https://www.ted.com/playlists/474/the_best_hans_rosling_talks_yo) even before *data science* was in my vocabulary. The animated graphs in his presentations would bring data to life. One of his signature graphs is re-created below using the dataset of global indicators provided by [Gapminder](https://www.gapminder.org/).

# %%
# Import necessary libraries
import pandas as pd
import numpy as np

import plotly.io as pio
import plotly.graph_objects as go
# Set default renderer for VS Code/Jupyter environments
pio.renderers.default = "notebook_connected"
from bubbly.bubbly import bubbleplot

# Load datasets with correct local paths
gapminder_indicators = pd.read_csv('gapminder/gapminder.tsv', delimiter='\t')
honey_production = pd.read_csv('honey-production-in-us/honeyproduction.csv')
world_happiness = pd.read_csv('world happiness index/2017.csv')

print("Datasets loaded successfully!")
print(f"Gapminder shape: {gapminder_indicators.shape}")
print(f"Honey production shape: {honey_production.shape}")
print(f"World happiness shape: {world_happiness.shape}")
# Out:
# Datasets loaded successfully!
# Gapminder shape: (1704, 6)
# Honey production shape: (626, 8)
# World happiness shape: (155, 12)

# %% [markdown]
# Using the function `bubbleplot` from the module [`bubbly`(bubble charts with plotly)](https://github.com/AashitaK/bubbly):

# %%
import plotly.express as px

# Create animated bubble chart using plotly.express (modern approach)
figure = px.scatter(gapminder_indicators, 
                   x='gdpPercap', 
                   y='lifeExp',
                   size='pop', 
                   color='continent',
                   hover_name='country',
                   animation_frame='year',
                   log_x=True,
                   size_max=60,
                   title='Gapminder Global Indicators',
                   labels={'gdpPercap': 'GDP per Capita', 
                          'lifeExp': 'Life Expectancy',
                          'pop': 'Population',
                          'continent': 'Continent'})

figure.update_layout(height=650)
figure.show(renderer="notebook_connected")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="4a1b91db-bc8d-4ab8-b024-8c8093c7cc7e" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("4a1b91db-bc8d-4ab8-b024-8c8093c7cc7e")) {                    Plotly.newPlot(                        "4a1b91db-bc8d-4ab8-b024-8c8093c7cc7e",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eContinent=Asia\u003cbr\u003eyear=1952\u003cbr\u003eGDP per Capita=%{x}\u003cbr\u003eLife Expectancy=%{y}\u003cbr\u003ePopulation=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Afghanistan","Bahrain","Bangladesh","Cambodia","China","Hong Kong, China","India","Indonesia","Iran","Iraq","Israel","Japan","Jordan","Korea, Dem. Rep.","Korea, Rep.","Kuwait","Lebanon","Malaysia","Mongolia","Myanmar","Nepal","Oman","Pakistan","Philippines","Saudi Arabia","Singapore","Sri Lanka","Syria","Taiwan","Thailand","Vietnam","West Bank and Gaza","Yemen, Rep."],"legendgroup":"Asia","marker":{"color":"#636efa","size":{"dtype":"i4","bdata":"dY+AAH\u002fWAQDLb8sCTJ9HAGfoJyFMcCAAAEUsFqAD5ATAjAcB5ghTALK7GACRQicFqkYJANBGhwBzoj8BAHECACn3FQDa+GYAlzcMAESYMgFIHYwAub8HAADmdgIjY1YBLR89AFgyEQAGzXkA7d43ANp3ggC62UQBt36QAbm5DwD1vUsA"},"sizemode":"area","sizeref":366300.86,"symbol":"circle"},"mode":"markers","name":"Asia","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"em8MAZBbiEBsW5TZikXDQOVkPRD0YYVAvQeeMYIHd0AEWrqCLQd5QJC\"},"xaxis":"x","y":{"dtype":"f8","bdata":"kxgEVg7NPEDVeOkmMXhJQMuhRbbzvUJATDeJQWC1Q0AAAAAAAABGQHsUrkfhek5AObTIdr6vQkCWQ4ts57tCQKwcWmQ7b0ZAKVyPwvWoRkApXI\u002fC9VhQQKRwPQrXg09ATmIQWDmURUC6SQwCKwdJQESLbOf7uUdAuB6F61HIS0AQWDm0yPZLQCUGgZVDO0hArBxaZDsfRUBGtvP91ChCQGq8dJMYFEJARIts5\u002fvJQkArhxbZzrdFQMdLN4lB4EdAAAAAAADwQ0Cmm8QgsDJOQJZDi2zny0xAGy\u002fdJAbxRkAAAAAAAEBNQAaBlUOLbElA2\u002fl+arw0REAUrkfhepRFQKAaL90kRkBA"},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eContinent=Europe\u003cbr\u003eyear=1952\u003cbr\u003eGDP per Capita=%{x}\u003cbr\u003eLife Expectancy=%{y}\u003cbr\u003ePopulation=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Albania","Austria","Belgium","Bosnia and Herzegovina","Bulgaria","Croatia","Czech Republic","Denmark","Finland","France","Germany","Greece","Hungary","Iceland","Ireland","Italy","Montenegro","Netherlands","Norway","Poland","Portugal","Romania","Serbia","Slovak Republic","Slovenia","Spain","Sweden","Switzerland","Turkey","United Kingdom"],"legendgroup":"Europe","marker":{"color":"#EF553B","size":{"dtype":"i4","bdata":"iZITAJy1aQAlN4UAWJYqAJQBbwD1PDsAPz2LALAhQgCEaj4AE+KHAmAVHwQCAHYAAAWRAPpBAgDcCy0AUFPXAopQBgCkap4A8MYyAPediAHiGIIA8MD9AHOtaAD5SjYAbroWAO6iswHBtmwAmHhJAB1KUwEwgAED"},"sizemode":"area","sizeref":366300.86,"symbol":"circle"},"mode":"markers","name":"Europe","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"gzC3ezkEmUBozvqUE\u002fm3QHcxzXSNS8BALqOi+0NsjkDt0obDkhijQLNBJhl5XqhARIts5yPcukD5SbVPMe7CQE1J1uGEGLlAxeQNMM91u0DkEdxIHei7QBk6dlBhlatAhpM0f6yPtECnQdE8sGO8QCdok8NHWrRAhLuzdmdDs0AD7+TTK6+kQPqXpDLJdsFACcTr+rW3w0AMrU7OqHqvQCSAm8Wj+KdAu\u002fCD8zmRqEBtrMQ86\u002fqrQKosCruo0rNA58WJrwp3sECYE7TJEfStQBZp4h3sp8BAEoPAyh3HzEAzFk1nZ8SeQLgdGhbBfcNA"},"xaxis":"x","y":{"dtype":"f8","bdata":"PQrXo3CdS0AzMzMzM7NQQAAAAAAAAFFAKVyPwvXoSkDNzMzMzMxNQHsUrkfhmk5ASOF6FK63UEBSuB6F67FRQDMzMz ...

# %% [markdown]
# In the graph above, the size corresponds to the population of each country and the values of GDP per capital and life expectency along with the name of the country can be seen by hovering over the cursor on the bubbles.

# %% [markdown]
# The animated bubble charts convey a great deal of information since they can accomodate upto *seven variables* in total, namely:
# * X-axis (GDP per capita)
# * Y-axis (Life Expectancy)
# * Z-axis
# * Bubbles (Countries, can be seen by hovering the cursor over the dots)
# * Time (in years)
# * Size of bubbles (Population)
# * Color of bubbles (Continents, variable can be categorical or numerical)
#
# This means that these captivating graphs can be used very creatively on different datasets to convey a lot of information in a compact manner. The code for plotting them ran over 300 lines and hence I decided to write a python module [`bubbly`](https://github.com/AashitaK/bubbly), short form for bubble charts with plotly, from which the function `bubbleplot` is imported. The function has the following self-explanatory arguments:
# * dataset (pandas DataFrame)
# * x_column (numerical column)
# * y_column (numerical column)
# * z_column (optional, numerical column)
# * bubble_column (numerical or categorical column)
# * time_column (optional, numerical column)
# * size_column (optional, numerical column)
# * color_column (optional, can be either `category`, `object`, `bool`, `int` or `float` dtype)
#
# More arguments for formatting the plots:
# * x_title (optional)
# * y_title (optional)
# * z_title (optional)
# * title (optional)
# * colorbar_title (optional, ignored in case of categorical color_column)
# * x_logscale (optional: True or False, default: False)
# * y_logscale (optional: True or False, default: False)
# * z_logscale (optional: True or False, default: False)
# * x_range (optional)
# * y_range (optional)
# * z_range (optional)
# * scale_bubble (optional, default: 1)
# * colorscale (optional, ignored in case of categorical color_column)
# * width (optional)
# * height (optional)
# * show_slider (optional: True or False, default: True)
# * show_button (optional: True or False, default: True)
# * show_colorbar (optional: True or False, default: True, ignored in case of categorical color_column)
#
#
# The function `bubbleplot` is ready-to-use on any suitable dataset, so you are welcome to use it in your kernels, simply by adding `AashitaK/bubbly` as a custom package in the settings section. I would appreciate a reference with link to this kernel and/or the module  [`bubbly`](https://github.com/AashitaK/bubbly) in case you do so.
#
# Below are more charts on [Honey production dataset](https://www.kaggle.com/jessicali9530/honey-production/kernels) using the function `bubbleplot` from the module [`bubbly`](https://github.com/AashitaK/bubbly):

# %%
import plotly.express as px

# Honey production animated bubble chart using plotly.express
figure = px.scatter(honey_production, 
                   x='totalprod', 
                   y='prodvalue',
                   size='yieldpercol', 
                   color='numcol',
                   hover_name='state',
                   animation_frame='year',
                   log_x=True,
                   log_y=True,
                   size_max=60,
                   title='Timeline of honey production for each state in USA',
                   labels={'totalprod': 'Total Production', 
                          'prodvalue': 'Production Value',
                          'yieldpercol': 'Yield per Colony',
                          'numcol': '# Colonies'},
                   color_continuous_scale='Viridis')

figure.update_layout(height=650)
figure.update_coloraxes(colorbar_title="# Colonies")
figure.show(renderer="notebook_connected")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="5d3961c3-f234-40e5-9a0c-4b2ff8ed2b98" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("5d3961c3-f234-40e5-9a0c-4b2ff8ed2b98")) {                    Plotly.newPlot(                        "5d3961c3-f234-40e5-9a0c-4b2ff8ed2b98",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eyear=1998\u003cbr\u003eTotal Production=%{x}\u003cbr\u003eProduction Value=%{y}\u003cbr\u003eYield per Colony=%{marker.size}\u003cbr\u003e# Colonies=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["AL","AZ","AR","CA","CO","FL","GA","HI","ID","IL","IN","IA","KS","KY","LA","ME","MD","MI","MN","MS","MO","MT","NE","NV","NJ","NM","NY","NC","ND","OH","OK","OR","PA","SD","TN","TX","UT","VT","VA","WA","WV","WI","WY"],"legendgroup":"","marker":{"color":{"dtype":"f8","bdata":"AAAAAABAz0AAAAAAANvqQAAAAAAA4elAAAAAAEB3G0EAAAAAAF7aQAAAAACAEwxBAAAAAIBP8kAAAAAAAEC\u002fQAAAAAAATP1AAAAAAACUwUAAAAAAAJTBQAAAAAAAauhAAAAAAABAz0AAAAAAAHCnQAAAAAAABeRAAAAAAACIw0AAAAAAAFi7QAAAAAAAiPNAAAAAAAAXAUEAAAAAAJTRQAAAAAAAdtZAAAAAAIAT\u002fEAAAAAAAEDvQAAAAAAAiMNAAAAAAAB8xUAAAAAAAFjLQAAAAAAAve9AAAAAAABAv0AAAAAAgBMMQQAAAAAAlNFAAAAAAABAr0AAAAAAAGroQAAAAAAAZNlAAAAAAEB3C0EAAAAAAFi7QAAAAACAN\u002fZAAAAAAABM3UAAAAAAAHC3QAAAAAAAQL9AAAAAAABS7EAAAAAAAHC3QAAAAACAuvVAAAAAAAB25kA="},"coloraxis":"coloraxis","size":{"dtype":"i2","bdata":"RwA8AEEAUwBIAGIAOAB2ADIARwBcAE4ALgAyAG8AGgAsAFUATwBWAEIAegBGAC4AMQA3AFAAOwCAAE4AMwAtAEIAXwBAAE0AOgBAACUAMwA3AFsAPAA="},"sizemode":"area","sizeref":0.03777777777777778,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"..."},"xaxis":"x","y":{"dtype":"f8","bdata":"..."},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[ ...

# %%
import plotly.express as px

# Honey production price analysis using plotly.express
figure = px.scatter(honey_production, 
                   x='prodvalue', 
                   y='priceperlb',
                   size='yieldpercol', 
                   color='numcol',
                   hover_name='state',
                   animation_frame='year',
                   log_x=True,
                   log_y=True,
                   size_max=60,
                   title='Timeline of honey production and its prices for each state in USA',
                   labels={'prodvalue': 'Production Value', 
                          'priceperlb': 'Price per Pound',
                          'yieldpercol': 'Yield per Colony (lbs)',
                          'numcol': '# Colonies'},
                   color_continuous_scale='Blackbody',
                   range_y=[0.1, 1.0])  # Adjusted range to avoid log issues with negative values

figure.update_layout(height=650)
figure.update_coloraxes(colorbar_title="# Colonies")
figure.show(renderer="notebook_connected")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="f64d4d27-9afa-4bdb-b71f-4bbed0e46e7e" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f64d4d27-9afa-4bdb-b71f-4bbed0e46e7e")) {                    Plotly.newPlot(                        "f64d4d27-9afa-4bdb-b71f-4bbed0e46e7e",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eyear=1998\u003cbr\u003eProduction Value=%{x}\u003cbr\u003ePrice per Pound=%{y}\u003cbr\u003eYield per Colony (lbs)=%{marker.size}\u003cbr\u003e# Colonies=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["AL","AZ","AR","CA","CO","FL","GA","HI","ID","IL","IN","IA","KS","KY","LA","ME","MD","MI","MN","MS","MO","MT","NE","NV","NJ","NM","NY","NC","ND","OH","OK","OR","PA","SD","TN","TX","UT","VT","VA","WA","WV","WI","WY"],"legendgroup":"","marker":{"color":{"dtype":"f8","bdata":"AAAAAABAz0AAAAAAANvqQAAAAAAA4elAAAAAAEB3G0EAAAAAAF7aQAAAAACAEwxBAAAAAIBP8kAAAAAAAEC\u002fQAAAAAAATP1AAAAAAACUwUAAAAAAAJTBQAAAAAAAauhAAAAAAABAz0AAAAAAAHCnQAAAAAAABeRAAAAAAACIw0AAAAAAAFi7QAAAAAAAiPNAAAAAAAAXAUEAAAAAAJTRQAAAAAAAdtZAAAAAAIAT\u002fEAAAAAAAEDvQAAAAAAAiMNAAAAAAAB8xUAAAAAAAFjLQAAAAAAAve9AAAAAAABAv0AAAAAAgBMMQQAAAAAAlNFAAAAAAABAr0AAAAAAAGroQAAAAAAAZNlAAAAAAEB3C0EAAAAAAFi7QAAAAACAN\u002fZAAAAAAABM3UAAAAAAAHC3QAAAAAAAQL9AAAAAAABS7EAAAAAAAHC3QAAAAACAuvVAAAAAAAB25kA="},"coloraxis":"coloraxis","size":{"dtype":"i2","bdata":"RwA8AEEAUwBIAGIAOAB2ADIARwBcAE4ALgAyAG8AGgAsAFUATwBWAEIAegBGAC4AMQA3AFAAOwCAAE4AMwAtAEIAXwBAAE0AOgBAACUAMwA3AFsAPAA="},"sizemode":"area","sizeref":0.03777777777777778,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"..."},"xaxis":"x","y":{"dtype":"f8","bdata":"CtejcD0K5z97FK5H4XrkP+F6FK5H4eI\u002f16NwPQrX4z9mZmZmZmbmP3sUrkfheuQ\u002fFK5H4XoU5j+kcD0K16PoP83MzMzMzOQ\u002fCtejcD0K8z8zMzMzMzPrP2ZmZmZmZuY\u002f16NwPQrX6z9mZmZmZmb2P+F6FK5H4eI\u002fFK5H4XoU5j+amZmZmZnxPx+F61G4HuU\u002fzczMzMzM5D+PwvUoXI\u002fiP1K4HoXrUeg\u002fexSuR+F65D+F61G4HoXrP2ZmZmZmZvo\u002fUrgehetR6D9SuB6F61HoP2ZmZmZmZuY\u002fFK5H4XoU9j8pXI\u002fC9SjkP4\u002fC9Shcj+o\u002f16NwPQrX8z\u002fNzMzMzMzsP5qZmZmZmek\u002fexSuR+F65D8fhetRuB71P9ejcD0K1+M\u002fzczMzMzM5D8zMzMzMzPrP0jhehSuR\u002fU\u002fexSuR+F65D89CtejcD3yPwrXo3A9Cuc\u002fw\u002fUoXI\u002fC5T8="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks": ...

# %%
import plotly.express as px

# Honey production stocks analysis using plotly.express
figure = px.scatter(honey_production, 
                   x='totalprod', 
                   y='stocks',
                   size='numcol', 
                   color='yieldpercol',
                   hover_name='state',
                   animation_frame='year',
                   log_x=True,
                   log_y=True,
                   size_max=60,
                   title='Timeline of total honey production and its stock value for each state in USA',
                   labels={'totalprod': 'Total Production', 
                          'stocks': 'Stocks',
                          'numcol': '# Colonies',
                          'yieldpercol': 'Yield per Colony (lbs)'},
                   color_continuous_scale='earth')

figure.update_layout(height=650)
figure.update_coloraxes(colorbar_title="Yield per Colony (lbs)")
figure.show(renderer="notebook_connected")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="1be7e1a2-b787-47ed-8a6a-be6eda30941b" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1be7e1a2-b787-47ed-8a6a-be6eda30941b")) {                    Plotly.newPlot(                        "1be7e1a2-b787-47ed-8a6a-be6eda30941b",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eyear=1998\u003cbr\u003eTotal Production=%{x}\u003cbr\u003eStocks=%{y}\u003cbr\u003e# Colonies=%{marker.size}\u003cbr\u003eYield per Colony (lbs)=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["AL","AZ","AR","CA","CO","FL","GA","HI","ID","IL","IN","IA","KS","KY","LA","ME","MD","MI","MN","MS","MO","MT","NE","NV","NJ","NM","NY","NC","ND","OH","OK","OR","PA","SD","TN","TX","UT","VT","VA","WA","WV","WI","WY"],"legendgroup":"","marker":{"color":{"dtype":"i2","bdata":"RwA8AEEAUwBIAGIAOAB2ADIARwBcAE4ALgAyAG8AGgAsAFUATwBWAEIAegBGAC4AMQA3AFAAOwCAAE4AMwAtAEIAXwBAAE0AOgBAACUAMwA3AFsAPAA="},"coloraxis":"coloraxis","size":{"dtype":"f8","bdata":"AAAAAABAz0AAAAAAANvqQAAAAAAA4elAAAAAAEB3G0EAAAAAAF7aQAAAAACAEwxBAAAAAIBP8kAAAAAAAEC\u002fQAAAAAAATP1AAAAAAACUwUAAAAAAAJTBQAAAAAAAauhAAAAAAABAz0AAAAAAAHCnQAAAAAAABeRAAAAAAACIw0AAAAAAAFi7QAAAAAAAiPNAAAAAAAAXAUEAAAAAAJTRQAAAAAAAdtZAAAAAAIAT\u002fEAAAAAAAEDvQAAAAAAAiMNAAAAAAAB8xUAAAAAAAFjLQAAAAAAAve9AAAAAAABAv0AAAAAAgBMMQQAAAAAAlNFAAAAAAABAr0AAAAAAAGroQAAAAAAAZNlAAAAAAEB3C0EAAAAAAFi7QAAAAACAN\u002fZAAAAAAABM3UAAAAAAAHC3QAAAAAAAQL9AAAAAAABS7EAAAAAAAHC3QAAAAACAuvVAAAAAAAB25kA="},"sizemode":"area","sizeref":141.66666666666666,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"..."},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAMBoA0EAAAAAyKg2QQAAAADAwTlBAAAAAI6CZ0EAAAAAkFI4QQAAAABYMlFBAAAAAOC8EkEAAAAAAB3wQAAAAADw70BBAAAAAADnCEEAAAAAoNgdQQAAAAAkjkFBAAAAAMDNF0EAAAAAAOfoQAAAAADQZSpBAAAAAICQ\u002fEAAAAAAAHb2QAAAAADgA0xBAAAAAGQYRUEAAAAAoGcrQQAAAABgxRtBAAAAAMDfVEEAAAAAABdBQQAAAADAXAVBAAAAAMBiBEEAAAAAwK8cQQAAAABwpUJBAAAAAMBuAkEAAAAAgNhgQQAAAABgbCVBAAAAAADD7kAAAAAAILg4QQAAAAAQFChBAAAAAMHKZEEAAAAAgIr9QAAAAADgmDhBAAAAAJD\u002fIEEAAAAAwEQJQQAAAAAA\u002f\u002fRAAAAAAGjENEEAAAAAwOsCQQAAAACgFFRBAAAAAID7H0E="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0, ...

# %% [markdown]
# # Some static charts:
# It is not always the case that animated bubble charts are most suitable for use. The package [`bubbly`](https://github.com/AashitaK/bubbly/) very well supports non-animated charts as well.
#
# The following static chart conveys it better that the regional inequality in GDP per capita is increasing over the last decade.

# %%
gapminder_indicators_continents = gapminder_indicators.groupby(['continent', 'year'], as_index=False)[['gdpPercap', 'lifeExp', 'pop']].mean()

# Static chart showing GDP per capita by continent over time
figure = px.scatter(gapminder_indicators_continents, 
                   x='year', 
                   y='gdpPercap',
                   size='pop', 
                   color='continent',
                   hover_name='continent',
                   size_max=60,
                   title='GDP per capita inequality among geographical regions is increasing over time',
                   labels={'year': 'Years', 
                          'gdpPercap': 'GDP per Capita',
                          'pop': 'Population',
                          'continent': 'Continent'},
                   range_x=[1945, 2015],
                   range_y=[0, 35000])

figure.update_layout(height=650)
figure.show(renderer="notebook_connected")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="2117d3f3-3895-444a-8ed2-ece7d2c7cbd1" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("2117d3f3-3895-444a-8ed2-ece7d2c7cbd1")) {                    Plotly.newPlot(                        "2117d3f3-3895-444a-8ed2-ece7d2c7cbd1",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eContinent=Africa\u003cbr\u003eYears=%{x}\u003cbr\u003eGDP per Capita=%{y}\u003cbr\u003ePopulation=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa"],"legendgroup":"Africa","marker":{"color":"#636efa","size":{"dtype":"f8","bdata":"2YmdaOZuUUE7sRNbqm1TQYqd2NmZwFVBYid2ssCYWEFiJ3byJ95bQRQ7sSPoxF9BdmInLuVQYkEUO7HDtBVlQYqd2JHKLGhBT+zEDpxIa0EndmIHsJRuQcVO7DQzDHFB"},"sizemode":"area","sizeref":32087.153425925924,"symbol":"circle"},"mode":"markers","name":"Africa","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"oAelB6oHrwe0B7kHvgfDB8gHzQfSB9cH"},"xaxis":"x","y":{"dtype":"f8","bdata":"vO96NEqSk0Bl0U268aSVQF\u002fhdbdQ+JhAFyQbRLoEoEB3A6Y5O0eiQCxrLoTgM6RAOr1rmC9jo0C3ugWGVtWhQKq9\u002f+Oe06FAigRo5ISVokDvy4szxU6kQEFqkbEQIqhA"},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eContinent=Americas\u003cbr\u003eYears=%{x}\u003cbr\u003eGDP per Capita=%{y}\u003cbr\u003ePopulation=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas","Americas"],"legendgroup":"Americas","marker":{"color":"#EF553B","size":{"dtype":"f8","bdata":"rkfhOkJVakFI4XqUsYVtQSlcj6Inh3BB7FG4jspWckFmZmaGxDF0QfYoXD8xDXZBzczMTC8LeEHXo3DthAt6QSlcj0J5M3xBZmZmBjtmfkE9CtfzRzWAQa5H4foEJYFB"},"sizemode":"area","sizeref":32087.153425925924,"symbol":"circle"},"mode":"markers","name":"Americas","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"oAelB6oHrwe0B7kHvgfDB8gHzQfSB9cH"},"xaxis":"x","y":{"dtype":"f8","bdata":"lorXBiDer0DzqxgyCwiyQKy+BLiKJbNAd9Ed5UAktkAd2SKKVVu5QIwjB9MBuLxA3+3NsbxSvUBDRIN3ZnG+QJo9MzXvbL9A5ROqgqZcwUCk4XOr1iPCQHa\u002fTAyEfcVA"},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eContinent=Asia\u003cbr\u003eYears=%{x}\u003cbr\u003eGDP per Capita=%{y}\u003cbr\u003ePopulation=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia"],"legendgroup":"Asia","marker":{"color":"#00cc96","size":{"dtype":"f8","bdata":"jC66IJEphEFtssne4ZSGQYwuutj+gohBTjbZBD2Ji0GbbLKJqRSPQaOLLgpHOpFB6aKLppPbkkHwwQeHd76UQU422WAuo5ZBwgcfbI5xmEGTTTbFtgWaQVVVVWFmiptB"},"sizemode":"area","sizeref":32087.153425925924,"symbol":"circle"},"mode":"markers","name":"Asia","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"oAelB6oHrwe0B7kHvgfDB8gHzQfSB9cH"},"xaxis":"x","y":{"dtype":"f8","bdata":"VFCw53tLtECluvOhu5u2QKyzup9eYbZABXA2YixTt0Dl4q\u002f8d\u002fu\u002fQPEynGNQb75APFGumSIKvUDwHWn8Obi9QOWhCVrY38BAj0QZ8Qs1w0DIdh2SC9\u002fDQPQDe3CDXMhA"},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eContinent=Europe\u003cbr\u003eYears=%{x}\u003cbr\u003eGDP per Capita=%{y}\u003cbr\u003ePopulation=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe"],"legendgroup":"Europe","marker":{"color":"#ab63 ...

# %% [markdown]
# In the following chart, time is denoted by color to show that even though Vietnam lags far behind Hungary in terms of GDP per capita, it has catched up with the same level of life expentancy within a decade starting far below.  The size of bubbles corresponds to the population.

# %%
import plotly.express as px

dataset = gapminder_indicators[gapminder_indicators['country'].isin(['Hungary', 'Vietnam'])]

# Hungary vs Vietnam comparison using time as color
figure = px.scatter(dataset, 
                   x='gdpPercap', 
                   y='lifeExp',
                   size='pop', 
                   color='year',
                   hover_name='country',
                   log_x=True,
                   size_max=60,
                   title='GDP per capita and Life Expectancy of Hungary and Vietnam over time',
                   labels={'gdpPercap': 'GDP per Capita', 
                          'lifeExp': 'Life Expectancy',
                          'pop': 'Population',
                          'year': 'Time in years'},
                   color_continuous_scale='viridis')

figure.update_layout(height=650)
figure.update_coloraxes(colorbar_title="Time in years")
figure.show(renderer="notebook_connected")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="b41f35a4-eaed-4ffe-adf2-d8fb5537ffc0" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b41f35a4-eaed-4ffe-adf2-d8fb5537ffc0")) {                    Plotly.newPlot(                        "b41f35a4-eaed-4ffe-adf2-d8fb5537ffc0",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eGDP per Capita=%{x}\u003cbr\u003eLife Expectancy=%{y}\u003cbr\u003ePopulation=%{marker.size}\u003cbr\u003eTime in years=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Hungary","Hungary","Hungary","Hungary","Hungary","Hungary","Hungary","Hungary","Hungary","Hungary","Hungary","Hungary","Vietnam","Vietnam","Vietnam","Vietnam","Vietnam","Vietnam","Vietnam","Vietnam","Vietnam","Vietnam","Vietnam","Vietnam"],"legendgroup":"","marker":{"color":{"dtype":"i2","bdata":"oAelB6oHrwe0B7kHvgfDB8gHzQfSB9cHoAelB6oHrwe0B7kHvgfDB8gHzQfSB9cH"},"coloraxis":"coloraxis","size":{"dtype":"i4","bdata":"AAWRAJghlgCYjJkAPv+bAOuZngBzT6IAf1qjAATwoQCM6J0ATFKcAPHbmQAM65cAt36QAY97ugEssAMC5itaAqZhqQKCFAMDZalYA\u002funvgP4NSsEZGqIBHOP0gQUABUF"},"sizemode":"area","sizeref":23683.987777777777,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"hpM0f6yPtEDsbTMVLpi3QJUp5iBcfr1AW+uLhFI3wkBKmGn7U9zDQFOu8C5rzcZAumbyzf6AyEBeEfxvPV3JQPOOU3TQk8RAxLEubmPgxkC5GW7A9\u002f3MQEJ4tHE8ltFApefMLIjogkC5LduYSCKFQB5aGq5kIIhAuzPJfvzog0DaXftdA9yFQFNgXAVMTIZAwnrt4+IZhkCiI15DZaaJQI\u002frlWgv6I5ARNycSpanlUBXryKj05GbQJHSbB4nE6NA"},"xaxis":"x","y":{"dtype":"f8","bdata":"UrgehesBUEAK16NwPZpQQD0K16Nw\u002fVBAAAAAAABgUUBxPQrXo3BRQM3MzMzMfFFAKVyPwvVYUUCF61G4HmVRQHsUrkfhSlFAw\u002fUoXI\u002fCUUD2KFyPwiVSQBKDwMqhVVJA2\u002fl+arw0RECoxks3iXFFQFg5tMh2rkZAJQaBlUPrR0CNl24SgyBJQG8Sg8DK4UtAnMQgsHJoTUApXI\u002fC9WhPQO58PzVe6lBAXrpJDAKrUUAMAiuHFkFSQA4tsp3vj1JA"},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewid ...

# %% [markdown]
# The above chart captures the common pattern among many emerging nations that the human development indicators first rise steeply followed by economic indicators, unlike the development patterns of the western nations in the past century.

# %% [markdown]
# # Some 3D charts

# %% [markdown]
# Data for the following chart comes from [World Happiness Report](https://www.kaggle.com/unsdsn/world-happiness) and the size of the bubbles corresponds to the generosity of nations.

# %%
import plotly.express as px

# 3D World Happiness chart using plotly.express
figure = px.scatter_3d(world_happiness, 
                      x='Economy..GDP.per.Capita.', 
                      y='Health..Life.Expectancy.',
                      z='Trust..Government.Corruption.',
                      size='Generosity', 
                      color='Happiness.Score',
                      hover_name='Country',
                      size_max=30,
                      title='Impact of Economy, Health and Govt. on Happiness Scores of Nations',
                      labels={'Economy..GDP.per.Capita.': 'GDP per Capita', 
                             'Health..Life.Expectancy.': 'Life Expectancy',
                             'Trust..Government.Corruption.': 'Corruption',
                             'Generosity': 'Generosity',
                             'Happiness.Score': 'Happiness Score'},
                      color_continuous_scale='Portland',
                      opacity=1.0)

figure.update_layout(height=650)
figure.update_coloraxes(colorbar_title="Happiness Score")
figure.show(renderer="notebook_connected")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="cb73a424-14ef-4f2b-a3ce-4f4a988756fa" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("cb73a424-14ef-4f2b-a3ce-4f4a988756fa")) {                    Plotly.newPlot(                        "cb73a424-14ef-4f2b-a3ce-4f4a988756fa",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eGDP per Capita=%{x}\u003cbr\u003eLife Expectancy=%{y}\u003cbr\u003eCorruption=%{z}\u003cbr\u003eGenerosity=%{marker.size}\u003cbr\u003eHappiness Score=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Norway","Denmark","Iceland","Switzerland","Finland","Netherlands","Canada","New Zealand","Sweden","Australia","Israel","Costa Rica","Austria","United States","Ireland","Germany","Belgium","Luxembourg","United Kingdom","Chile","United Arab Emirates","Brazil","Czech Republic","Argentina","Mexico","Singapore","Malta","Uruguay","Guatemala","Panama","France","Thailand","Taiwan Province of China","Spain","Qatar","Colombia","Saudi Arabia","Trinidad and Tobago","Kuwait","Slovakia","Bahrain","Malaysia","Nicaragua","Ecuador","El Salvador","Poland","Uzbekistan","Italy","Russia","Belize","Japan","Lithuania","Algeria","Latvia","South Korea","Moldova","Romania","Bolivia","Turkmenistan","Kazakhstan","North Cyprus","Slovenia","Peru","Mauritius","Cyprus","Estonia","Belarus","Libya","Turkey","Paraguay","Hong Kong S.A.R., China","Philippines","Serbia","Jordan","Hungary","Jamaica","Croatia","Kosovo","China","Pakistan","Indonesia","Venezuela","Montenegro","Morocco","Azerbaijan","Dominican Republic","Greece","Lebanon","Portugal","Bosnia and Herzegovina","Honduras","Macedonia","Somalia","Vietnam","Nigeria","Tajikistan","Bhutan","Kyrgyzstan","Nepal","Mongolia","South Africa","Tunisia","Palestinian Territories","Egypt","Bulgaria","Sierra Leone","Cameroon","Iran","Albania","Bangladesh","Namibia","Kenya","Mozambique","Myanmar","Senegal","Zambia","Iraq","Gabon","Ethiopia","Sri Lanka","Armenia","India","Mauritania","Congo (Brazzaville)","Georgia","Congo (Kinshasa)","Mali","Ivory Coast","Cambodia","Sudan","Ghana","Ukraine","Uganda","Burkina Faso","Niger","Malawi","Chad","Zimbabwe","Lesotho","Angola","Afghanistan","Botswana","Benin","Madagascar","Haiti","Yemen","South Sudan","Liberia","Guinea","Togo","Rwanda","Syria","Tanzania","Burundi","Central African Republic"],"legendgroup":"","marker":{"color":{"dtype":"f8","bdata":"\u002fv\u002f\u002fX+MlHkADAAAghxYeQAQAAKAYBB5AAAAAINv5HUACAACAQeAdQPz\u002f\u002fz8Mgh1A\u002f\u002f\u002f\u002ff5VDHUADAABAiUEdQAMAAODQIh1AAwAA4NAiHUACAACgHNocQP3\u002f\u002f1\u002flUBxAAAAA4CQGHEACAAAA1fgbQP\u002f\u002f\u002f79y6BtABAAAANPNG0ADAABAYpAbQAAAAEC2cxtAAQAA4CLbGkAFAADgpZsaQAEAAECNlxpABQAAgD2KGkD9\u002f\u002f+\u002fnW8aQAQAAEBgZRpA\u002f\u002f\u002f\u002fP99PGkD\u002f\u002f\u002f9fukkaQAUAAOClGxpA\u002ff\u002f\u002fX+XQGUD9\u002f\u002f9f5dAZQAEAACDZzhlA\u002ff\u002f\u002fn5vEGUD8\u002f\u002f\u002f\u002fLLIZQAEAAMAgsBlAAwAAAKycGUAAAAAAAIAZQAAAAGCRbRlAAgAAgEFgGUD+\u002f\u002f8\u002fCKwYQAQAACCFaxhA+\u002f\u002f\u002fH1pkGEAEAACAFlkYQP\u002f\u002f\u002fx8EVhhAAQAAQLRIGED8\u002f\u002f8fMQgYQAUAAGASAxhA+\u002f\u002f\u002fH1rkF0D\u002f\u002f\u002f\u002ffTeIXQAEAAOAi2xdAAgAAoBzaF0AEAACg8dIXQAUAAIAUrhdABQAA4KWbF0D7\u002f\u002f+f7XwXQAIAAGBmZhdAAgAAoBxaF0ACAACgHFoXQAQAAMDMTBdA\u002ff\u002f\u002ff8BKF0D\u002f\u002f\u002f9fukkXQAQAAOCnRhdA\u002f\u002f\u002f\u002fn3A9F0D8\u002f\u002f8fMQgXQP\u002f\u002f\u002f\u002f8o3BZABAAAoBiEFkD8\u002f\u002f9f53sWQAQAAACqcRZABAAA4KdGFkD+\u002f\u002f+fmRkWQAAAAAAAABZAAgAAANX4FUD9\u002f\u002f\u002f\u002fU+MVQP3\u002f\u002f99RuBVA\u002fP\u002f\u002f33qUFUD7\u002f\u002f9fEFgVQPv\u002f\ ...

# %%
figure = px.scatter_3d(gapminder_indicators, 
                      x='pop', 
                      y='lifeExp',
                      z='gdpPercap',
                      color='continent',
                      hover_name='country',
                      animation_frame='year',
                      log_x=True,
                      log_z=True,
                      size_max=30,
                      title='Gapminder Global Indicators',
                      labels={'pop': 'Population', 
                             'lifeExp': 'Life Expectancy',
                             'gdpPercap': 'GDP per Capita',
                             'continent': 'Continent'},
                      opacity=0.8)

figure.update_layout(height=700)
figure.show(renderer="notebook_connected")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="147ead4a-26d5-4763-a46e-356acef4b4ff" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("147ead4a-26d5-4763-a46e-356acef4b4ff")) {                    Plotly.newPlot(                        "147ead4a-26d5-4763-a46e-356acef4b4ff",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eContinent=Asia\u003cbr\u003eyear=1952\u003cbr\u003ePopulation=%{x}\u003cbr\u003eLife Expectancy=%{y}\u003cbr\u003eGDP per Capita=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Afghanistan","Bahrain","Bangladesh","Cambodia","China","Hong Kong, China","India","Indonesia","Iran","Iraq","Israel","Japan","Jordan","Korea, Dem. Rep.","Korea, Rep.","Kuwait","Lebanon","Malaysia","Mongolia","Myanmar","Nepal","Oman","Pakistan","Philippines","Saudi Arabia","Singapore","Sri Lanka","Syria","Taiwan","Thailand","Vietnam","West Bank and Gaza","Yemen, Rep."],"legendgroup":"Asia","marker":{"color":"#636efa","opacity":0.8,"symbol":"circle"},"mode":"markers","name":"Asia","scene":"scene","showlegend":true,"x":{"dtype":"i4","bdata":"dY+AAH\u002fWAQDLb8sCTJ9HAGfoJyFMcCAAAEUsFqAD5ATAjAcB5ghTALK7GACRQicFqkYJANBGhwBzoj8BAHECACn3FQDa+GYAlzcMAESYMgFIHYwAub8HAADmdgIjY1YBLR89AFgyEQAGzXkA7d43ANp3ggC62UQBt36QAbm5DwD1vUsA"},"y":{"dtype":"f8","bdata":"kxgEVg7NPEDVeOkmMXhJQMuhRbbzvUJATDeJQWC1Q0AAAAAAAABGQHsUrkfhek5AObTIdr6vQkCWQ4ts57tCQKwcWmQ7b0ZAKVyPwvWoRkApXI\u002fC9VhQQKRwPQrXg09ATmIQWDmURUC6SQwCKwdJQESLbOf7uUdAuB6F61HIS0AQWDm0yPZLQCUGgZVDO0hArBxaZDsfRUBGtvP91ChCQGq8dJMYFEJARIts5\u002fvJQkArhxbZzrdFQMdLN4lB4EdAAAAAAADwQ0Cmm8QgsDJOQJZDi2zny0xAGy\u002fdJAbxRkAAAAAAAEBNQAaBlUOLbElA2\u002fl+arw0REAUrkfhepRFQKAaL90kRkBA"},"z":{"dtype":"f8","bdata":"em8MAZBbiEBsW5TZikXDQOVkPRD0YYVAvQeeMYIHd0AEWrqCLQd5QJC\"},"type":"scatter3d"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eContinent=Europe\u003cbr\u003eyear=1952\u003cbr\u003ePopulation=%{x}\u003cbr\u003eLife Expectancy=%{y}\u003cbr\u003eGDP per Capita=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Albania","Austria","Belgium","Bosnia and Herzegovina","Bulgaria","Croatia","Czech Republic","Denmark","Finland","France","Germany","Greece","Hungary","Iceland","Ireland","Italy","Montenegro","Netherlands","Norway","Poland","Portugal","Romania","Serbia","Slovak Republic","Slovenia","Spain","Sweden","Switzerland","Turkey","United Kingdom"],"legendgroup":"Europe","marker":{"color":"#EF553B","opacity":0.8,"symbol":"circle"},"mode":"markers","name":"Europe","scene":"scene","showlegend":true,"x":{"dtype":"i4","bdata":"iZITAJy1aQAlN4UAWJYqAJQBbwD1PDsAPz2LALAhQgCEaj4AE+KHAmAVHwQCAHYAAAWRAPpBAgDcCy0AUFPXAopQBgCkap4A8MYyAPediAHiGIIA8MD9AHOtaAD5SjYAbroWAO6iswHBtmwAmHhJAB1KUwEwgAED"},"y":{"dtype":"f8","bdata":"PQrXo3CdS0AzMzMzM7NQQAAAAAAAAFFAKVyPwvXoSkDNzMzMzMxNQHsUrkfhmk5ASOF6FK63UEBSuB6F67FRQDMzMzMzo1BACtejcD3aUEAAAAAAAOBQQNejcD0Kd1BAUrgehesBUECPwvUoXB9SQArXo3A9ulBAXI\u002fC9Sh8UECiRbbz\u002fZRNQLgehetRCFJAexSuR+EqUkBI4XoUrqdOQClcj8L16E1AZmZmZmaGTkBzaJHtfP9MQNejcD0KF1BAFK5H4XpkUEBcj8L1KDxQQNejcD0K91FASOF6FK5nUUB7FK5H4cpFQOxRuB6FS1FA"},"z":{"dtype":"f8","bdata":"gzC3ezkEmUBozvqUE\u002fm3QHcxzXSNS8BALqOi+0NsjkDt0obDkhijQLNBJhl5XqhARIts5yPcukD5SbVPMe7CQE1J1uGEGLlAxeQNMM91u0DkEdxIHei7QBk6dlBhlatAhpM0f6yPtECnQdE8sGO8QCdok8NHWrRAhLuzdmdDs0AD7+TTK6+kQPqXpDLJdsFACcTr+rW3w0 ...

# %% [markdown]
# # Building it from the scratch
#
# If you are like me, with the habit of taking things apart and putting them back together to learn and understand them fully, then below is a step-by-step guide to plotting interactive bubble charts using `Plotly` that only expands on the functions coded in the module  [`bubbly`](https://github.com/AashitaK/bubbly).
#
# ## Steps:
# * [Setting up the grid](#grid)
# * [Plotting basic scatter plot](#scatter)
# * [Adding animated time frames](#frames)
# * [Adding slider bar for time scale](#slider)
# * [Adding pause-play button](#button)
# * [Using bubble size as a variable](#size)
# * [Using colors to classify into categories](#color)
#
# Note: The following section is not required for going ahead to use  [`bubbly`](https://github.com/AashitaK/bubbly) to make fun animated bubble charts in your kernels using the function `bubbleplot`.
#
# We are using `Plotly` in offline mode for it is the [only mode that works in Kaggle](https://www.kaggle.com/residentmario/introduction-to-plotly-optional).

# %% [markdown]
# ## Setting up the grid <a name="grid"></a>

# %% [markdown]
# In the [`Plotly`'s official tutorial](https://plot.ly/python/gapminder-example/) for the animated bubble charts, the grids are made using the `Grid` and  `Column` objects from `plotly.grid_objs`. However, these objects are not supported for the offline mode and hence, they cannot be used as it is in Kaggle kernels. This can be fixed by simply defining the grid as a `pandas DataFrame` object and modifying the plotting of the time frames on the grid accordingly as shown below.

# %%
# Define the dataset and the columns
dataset = gapminder_indicators
x_column = 'gdpPercap'
y_column = 'lifeExp'
bubble_column = 'country'
time_column = 'year'

# %%
# Get the years in the dataset
years = dataset[time_column].unique()

# Make the grid using pd.concat instead of deprecated append
grid_rows = []
col_name_template = '{year}+{header}_grid'
for year in years:
    dataset_by_year = dataset[(dataset['year'] == int(year))]
    for col_name in [x_column, y_column, bubble_column]:
        # Each column name is unique
        temp = col_name_template.format(
            year=year, header=col_name
        )
        if dataset_by_year[col_name].size != 0:
            grid_rows.append({'value': list(dataset_by_year[col_name]), 'key': temp})

grid = pd.DataFrame(grid_rows)
grid.sample(10)
# Out:
#                                                 value                  key
# 23  [Afghanistan, Albania, Algeria, Angola, Argent...    1987+country_grid
# 11  [Afghanistan, Albania, Algeria, Angola, Argent...    1967+country_grid
# 7   [31.997, 64.82, 48.303, 34.0, 65.142, 70.93, 6...    1962+lifeExp_grid
# 15  [786.11336, 3533.00391, 4910.416756, 3008.6473...  1977+gdpPercap_grid
# 6   [853.10071, 2312.888958, 2550.81688, 4269.2767...  1962+gdpPercap_grid
# 20  [Afghanistan, Albania, Algeria, Angola, Argent...    1982+country_grid
# 22  [40.822, 72.0, 65.799, 39.906, 70.774, 76.32, ...    1987+lifeExp_grid
# 24  [649.3413952, 2497.437901, 5023.216647, 2627.8...  1992+gdpPercap_grid
# 26  [Afghanistan, Albania, Algeria, Angola, Argent...    1992+country_grid
# 29  [Afghanistan, Albania, Algeria, Angola, Argent...    1997+country_grid

# %% [markdown]
# ## Plotting basic scatter plot <a name="scatter"></a>

# %% [markdown]
# Once the grid is defined with the data points, we next use it to scatter the dataset for the earliest year viz. $1952$

# %%
import plotly.graph_objects as go

# Define figure
figure = {
    'data': [],
    'layout': {},
    'frames': []
}

# Get the earliest year
year = min(years)

# Make the trace
trace = {
    'x': grid.loc[grid['key']==col_name_template.format(
        year=year, header=x_column
    ), 'value'].values[0], 
    'y': grid.loc[grid['key']==col_name_template.format(
        year=year, header=y_column
    ), 'value'].values[0],
    'mode': 'markers',
    'text': grid.loc[grid['key']==col_name_template.format(
        year=year, header=bubble_column
    ), 'value'].values[0]
}
# Append the trace to the figure
figure['data'].append(trace)

# Convert to plotly graph object and plot the figure
fig = go.Figure(figure)
fig.show(renderer="notebook_connected")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="2d3ab7e2-7c6a-4467-a7a4-90411986b049" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("2d3ab7e2-7c6a-4467-a7a4-90411986b049")) {                    Plotly.newPlot(                        "2d3ab7e2-7c6a-4467-a7a4-90411986b049",                        [{"mode":"markers","text":["Afghanistan","Albania","Algeria","Angola","Argentina","Australia","Austria","Bahrain","Bangladesh","Belgium","Benin","Bolivia","Bosnia and Herzegovina","Botswana","Brazil","Bulgaria","Burkina Faso","Burundi","Cambodia","Cameroon","Canada","Central African Republic","Chad","Chile","China","Colombia","Comoros","Congo, Dem. Rep.","Congo, Rep.","Costa Rica","Cote d'Ivoire","Croatia","Cuba","Czech Republic","Denmark","Djibouti","Dominican Republic","Ecuador","Egypt","El Salvador","Equatorial Guinea","Eritrea","Ethiopia","Finland","France","Gabon","Gambia","Germany","Ghana","Greece","Guatemala","Guinea","Guinea-Bissau","Haiti","Honduras","Hong Kong, China","Hungary","Iceland","India","Indonesia","Iran","Iraq","Ireland","Israel","Italy","Jamaica","Japan","Jordan","Kenya","Korea, Dem. Rep.","Korea, Rep.","Kuwait","Lebanon","Lesotho","Liberia","Libya","Madagascar","Malawi","Malaysia","Mali","Mauritania","Mauritius","Mexico","Mongolia","Montenegro","Morocco","Mozambique","Myanmar","Namibia","Nepal","Netherlands","New Zealand","Nicaragua","Niger","Nigeria","Norway","Oman","Pakistan","Panama","Paraguay","Peru","Philippines","Poland","Portugal","Puerto Rico","Reunion","Romania","Rwanda","Sao Tome and Principe","Saudi Arabia","Senegal","Serbia","Sierra Leone","Singapore","Slovak Republic","Slovenia","Somalia","South Africa","Spain","Sri Lanka","Sudan","Swaziland","Sweden","Switzerland","Syria","Taiwan","Tanzania","Thailand","Togo","Trinidad and Tobago","Tunisia","Turkey","Uganda","United Kingdom","United States","Uruguay","Venezuela","Vietnam","West Bank and Gaza","Yemen, Rep.","Zambia","Zimbabwe"],"x":[779.4453145,1601.056136,2449.008185,3520.610273,5911.315053,10039.59564,6137.076492,9867.084765,684.2441716,8343.105127,1062.7522,2677.326347,973.5331948,851.2411407,2108.944355,2444.286648,543.2552413,339.2964587,368.4692856,1172.667655,11367.16112,1071.310713,1178.665927,3939.978789,400.448611,2144.115096,1102.990936,780.5423257,2125.621418,2627.009471,1388.594732,3119.23652,5586.53878,6876.14025,9692.385245,2669.529475,1397.717137,3522.110717,1418.822445,3048.3029,375.6431231,328.9405571,362.1462796,6424.519071,7029.809327,4293.476475,485.2306591,7144.114393,911.2989371,3530.690067,2428.237769,510.1964923,299.850319,1840.366939,2194.926204,3054.421209,5263.673816,7267.688428,546.5657493,749.6816546,3035.326002,4129.766056,5210.280328,4086.522128,4931.404155,2898.530881,3216.956347,1546.907807,853.540919,1088.277758,1030.592226,108382.3529,4834.804067,298.8462121,575.5729961,2387.54806,1443.011715,369.1650802,1831.132894,452.3369807,743.1159097,1967.955707,3478.125529,786.5668575,2647.585601,1688.20357,468.5260381,331.0,2423.780443,545.8657229,8941.571858,10556.57566,3112.363948,761.879376,1077.281856,10095.42172,1828.230307,684.5971438,2480.380334,1952.308701,3758.523437,1272.880995,4029.329699,3068.319867,3081.959785,2718.885295,3144.613186,493.3238752,879.5835855,6459.554823,1450.356983,3581.459448,879.7877358,2315.138227,5074.659104,4215.041741,1135.749842,4725.295531,3834.034742,1083.53203,1615.991129,1148.376626,8527.844662,14734.23275,1643.485354,1206.947913,716.6500721,757.7974177,859.8086567,3023.271928,1468.475631,1969.10098,734.753484,9979.508487,13990.48208,5716.766744,7689.799761,605.0664917,1515.592329,781.7175761,1147.388831,406.8841148],"y":[28.801,55.23,43.077,30.015,62.485,69.12,6 ...

# %% [markdown]
# We convert the `x-axis` into the logarithmic scale, which is more suitable for the visualization of our dataset. We set up the basic layout, noting that, in this case of changing frames, using `autorange` for the axes does not render the graph well, so we set up the ranges manually.

# %%
# Get the max and min range of both axes
xmin = min(np.log10(dataset[x_column]))*0.98
xmax = max(np.log10(dataset[x_column]))*1.02
ymin = min(dataset[y_column])*0.75
ymax = max(dataset[y_column])*1.25

# Modify the layout
figure['layout']['xaxis'] = {'title': 'GDP per Capita', 'type': 'log', 
                             'range': [xmin, xmax]}   
figure['layout']['yaxis'] = {'title': 'Life Expectancy', 
                             'range': [ymin, ymax]} 
figure['layout']['title'] = 'Gapminder Global Indicators'
figure['layout']['showlegend'] = False
figure['layout']['hovermode'] = 'closest'

# Convert to plotly graph object and plot the figure
fig = go.Figure(figure)
fig.show(renderer="notebook_connected")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="9d0c0702-f989-4f8a-a455-defd5981c346" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("9d0c0702-f989-4f8a-a455-defd5981c346")) {                    Plotly.newPlot(                        "9d0c0702-f989-4f8a-a455-defd5981c346",                        [{"mode":"markers","text":["Afghanistan","Albania","Algeria","Angola","Argentina","Australia","Austria","Bahrain","Bangladesh","Belgium","Benin","Bolivia","Bosnia and Herzegovina","Botswana","Brazil","Bulgaria","Burkina Faso","Burundi","Cambodia","Cameroon","Canada","Central African Republic","Chad","Chile","China","Colombia","Comoros","Congo, Dem. Rep.","Congo, Rep.","Costa Rica","Cote d'Ivoire","Croatia","Cuba","Czech Republic","Denmark","Djibouti","Dominican Republic","Ecuador","Egypt","El Salvador","Equatorial Guinea","Eritrea","Ethiopia","Finland","France","Gabon","Gambia","Germany","Ghana","Greece","Guatemala","Guinea","Guinea-Bissau","Haiti","Honduras","Hong Kong, China","Hungary","Iceland","India","Indonesia","Iran","Iraq","Ireland","Israel","Italy","Jamaica","Japan","Jordan","Kenya","Korea, Dem. Rep.","Korea, Rep.","Kuwait","Lebanon","Lesotho","Liberia","Libya","Madagascar","Malawi","Malaysia","Mali","Mauritania","Mauritius","Mexico","Mongolia","Montenegro","Morocco","Mozambique","Myanmar","Namibia","Nepal","Netherlands","New Zealand","Nicaragua","Niger","Nigeria","Norway","Oman","Pakistan","Panama","Paraguay","Peru","Philippines","Poland","Portugal","Puerto Rico","Reunion","Romania","Rwanda","Sao Tome and Principe","Saudi Arabia","Senegal","Serbia","Sierra Leone","Singapore","Slovak Republic","Slovenia","Somalia","South Africa","Spain","Sri Lanka","Sudan","Swaziland","Sweden","Switzerland","Syria","Taiwan","Tanzania","Thailand","Togo","Trinidad and Tobago","Tunisia","Turkey","Uganda","United Kingdom","United States","Uruguay","Venezuela","Vietnam","West Bank and Gaza","Yemen, Rep.","Zambia","Zimbabwe"],"x":[779.4453145,1601.056136,2449.008185,3520.610273,5911.315053,10039.59564,6137.076492,9867.084765,684.2441716,8343.105127,1062.7522,2677.326347,973.5331948,851.2411407,2108.944355,2444.286648,543.2552413,339.2964587,368.4692856,1172.667655,11367.16112,1071.310713,1178.665927,3939.978789,400.448611,2144.115096,1102.990936,780.5423257,2125.621418,2627.009471,1388.594732,3119.23652,5586.53878,6876.14025,9692.385245,2669.529475,1397.717137,3522.110717,1418.822445,3048.3029,375.6431231,328.9405571,362.1462796,6424.519071,7029.809327,4293.476475,485.2306591,7144.114393,911.2989371,3530.690067,2428.237769,510.1964923,299.850319,1840.366939,2194.926204,3054.421209,5263.673816,7267.688428,546.5657493,749.6816546,3035.326002,4129.766056,5210.280328,4086.522128,4931.404155,2898.530881,3216.956347,1546.907807,853.540919,1088.277758,1030.592226,108382.3529,4834.804067,298.8462121,575.5729961,2387.54806,1443.011715,369.1650802,1831.132894,452.3369807,743.1159097,1967.955707,3478.125529,786.5668575,2647.585601,1688.20357,468.5260381,331.0,2423.780443,545.8657229,8941.571858,10556.57566,3112.363948,761.879376,1077.281856,10095.42172,1828.230307,684.5971438,2480.380334,1952.308701,3758.523437,1272.880995,4029.329699,3068.319867,3081.959785,2718.885295,3144.613186,493.3238752,879.5835855,6459.554823,1450.356983,3581.459448,879.7877358,2315.138227,5074.659104,4215.041741,1135.749842,4725.295531,3834.034742,1083.53203,1615.991129,1148.376626,8527.844662,14734.23275,1643.485354,1206.947913,716.6500721,757.7974177,859.8086567,3023.271928,1468.475631,1969.10098,734.753484,9979.508487,13990.48208,5716.766744,7689.799761,605.0664917,1515.592329,781.7175761,1147.388831,406.8841148],"y":[28.801,55.23,43.077,30.015,62.485,69.12,6 ...

# %% [markdown]
# ## Adding animated time frames <a name="frames"></a>

# %% [markdown]
# Next we add frames for each year resulting in an animated graph, though not interactive yet.

# %%
for year in years:
    # Make a frame for each year
    frame = {'data': [], 'name': str(year)}
    
    # Make a trace for each frame
    trace = {
        'x': grid.loc[grid['key']==col_name_template.format(
            year=year, header=x_column
        ), 'value'].values[0],
        'y': grid.loc[grid['key']==col_name_template.format(
            year=year, header=y_column
        ), 'value'].values[0],
        'mode': 'markers',
        'text': grid.loc[grid['key']==col_name_template.format(
            year=year, header=bubble_column
        ), 'value'].values[0],
        'type': 'scatter'
    }
    # Add trace to the frame
    frame['data'].append(trace)
    # Add frame to the figure
    figure['frames'].append(frame) 

# Convert to plotly graph object and plot the figure
fig = go.Figure(figure)
fig.show(renderer="notebook_connected")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="2033db11-f400-45bf-89dc-8d48d04cd39a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("2033db11-f400-45bf-89dc-8d48d04cd39a")) {                    Plotly.newPlot(                        "2033db11-f400-45bf-89dc-8d48d04cd39a",                        [{"mode":"markers","text":["Afghanistan","Albania","Algeria","Angola","Argentina","Australia","Austria","Bahrain","Bangladesh","Belgium","Benin","Bolivia","Bosnia and Herzegovina","Botswana","Brazil","Bulgaria","Burkina Faso","Burundi","Cambodia","Cameroon","Canada","Central African Republic","Chad","Chile","China","Colombia","Comoros","Congo, Dem. Rep.","Congo, Rep.","Costa Rica","Cote d'Ivoire","Croatia","Cuba","Czech Republic","Denmark","Djibouti","Dominican Republic","Ecuador","Egypt","El Salvador","Equatorial Guinea","Eritrea","Ethiopia","Finland","France","Gabon","Gambia","Germany","Ghana","Greece","Guatemala","Guinea","Guinea-Bissau","Haiti","Honduras","Hong Kong, China","Hungary","Iceland","India","Indonesia","Iran","Iraq","Ireland","Israel","Italy","Jamaica","Japan","Jordan","Kenya","Korea, Dem. Rep.","Korea, Rep.","Kuwait","Lebanon","Lesotho","Liberia","Libya","Madagascar","Malawi","Malaysia","Mali","Mauritania","Mauritius","Mexico","Mongolia","Montenegro","Morocco","Mozambique","Myanmar","Namibia","Nepal","Netherlands","New Zealand","Nicaragua","Niger","Nigeria","Norway","Oman","Pakistan","Panama","Paraguay","Peru","Philippines","Poland","Portugal","Puerto Rico","Reunion","Romania","Rwanda","Sao Tome and Principe","Saudi Arabia","Senegal","Serbia","Sierra Leone","Singapore","Slovak Republic","Slovenia","Somalia","South Africa","Spain","Sri Lanka","Sudan","Swaziland","Sweden","Switzerland","Syria","Taiwan","Tanzania","Thailand","Togo","Trinidad and Tobago","Tunisia","Turkey","Uganda","United Kingdom","United States","Uruguay","Venezuela","Vietnam","West Bank and Gaza","Yemen, Rep.","Zambia","Zimbabwe"],"x":[779.4453145,1601.056136,2449.008185,3520.610273,5911.315053,10039.59564,6137.076492,9867.084765,684.2441716,8343.105127,1062.7522,2677.326347,973.5331948,851.2411407,2108.944355,2444.286648,543.2552413,339.2964587,368.4692856,1172.667655,11367.16112,1071.310713,1178.665927,3939.978789,400.448611,2144.115096,1102.990936,780.5423257,2125.621418,2627.009471,1388.594732,3119.23652,5586.53878,6876.14025,9692.385245,2669.529475,1397.717137,3522.110717,1418.822445,3048.3029,375.6431231,328.9405571,362.1462796,6424.519071,7029.809327,4293.476475,485.2306591,7144.114393,911.2989371,3530.690067,2428.237769,510.1964923,299.850319,1840.366939,2194.926204,3054.421209,5263.673816,7267.688428,546.5657493,749.6816546,3035.326002,4129.766056,5210.280328,4086.522128,4931.404155,2898.530881,3216.956347,1546.907807,853.540919,1088.277758,1030.592226,108382.3529,4834.804067,298.8462121,575.5729961,2387.54806,1443.011715,369.1650802,1831.132894,452.3369807,743.1159097,1967.955707,3478.125529,786.5668575,2647.585601,1688.20357,468.5260381,331.0,2423.780443,545.8657229,8941.571858,10556.57566,3112.363948,761.879376,1077.281856,10095.42172,1828.230307,684.5971438,2480.380334,1952.308701,3758.523437,1272.880995,4029.329699,3068.319867,3081.959785,2718.885295,3144.613186,493.3238752,879.5835855,6459.554823,1450.356983,3581.459448,879.7877358,2315.138227,5074.659104,4215.041741,1135.749842,4725.295531,3834.034742,1083.53203,1615.991129,1148.376626,8527.844662,14734.23275,1643.485354,1206.947913,716.6500721,757.7974177,859.8086567,3023.271928,1468.475631,1969.10098,734.753484,9979.508487,13990.48208,5716.766744,7689.799761,605.0664917,1515.592329,781.7175761,1147.388831,406.8841148],"y":[28.801,55.23,43.077,30.015,62.485,69.12,6 ...

# %% [markdown]
# The animation happened only once, right after executing the code. To be able to make it interactive, we add a slider bar for the time.

# %% [markdown]
# ## Adding slider bar for time scale <a name="slider"></a>

# %% [markdown]
# The function `add_slider_steps` used here is imported from the module  [`bubbly`](https://github.com/AashitaK/bubbly).

# %%
# Define add_slider_steps function locally to avoid bubbly dependency
def add_slider_steps(sliders_dict, year):
    slider_step = {'args': [
        [year],
        {'frame': {'duration': 300, 'redraw': False},
         'mode': 'immediate',
         'transition': {'duration': 300}}
    ],
    'label': str(year),  # Ensure label is a string
    'method': 'animate'}
    sliders_dict['steps'].append(slider_step)

figure['layout']['sliders'] = {
    'args': [
        'slider.value', {
            'duration': 400,
            'ease': 'cubic-in-out'
        }
    ],
    'initialValue': min(years),
    'plotlycommand': 'animate',
    'values': years,
    'visible': True
}
sliders_dict = {
    'active': 0,
    'yanchor': 'top',
    'xanchor': 'left',
    'currentvalue': {
        'font': {'size': 20},
        'prefix': 'Year:',
        'visible': True,
        'xanchor': 'right'
    },
    'transition': {'duration': 300, 'easing': 'cubic-in-out'},
    'pad': {'b': 10, 't': 50},
    'len': 0.9,
    'x': 0.1,
    'y': 0,
    'steps': []
}

for year in years:
    add_slider_steps(sliders_dict, year)
    
figure['layout']['sliders'] = [sliders_dict]

# Convert to plotly graph object and plot the figure
fig = go.Figure(figure)
fig.show(renderer="notebook_connected")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="69b3d7d4-75a9-4190-9e51-f08a7b705c7d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("69b3d7d4-75a9-4190-9e51-f08a7b705c7d")) {                    Plotly.newPlot(                        "69b3d7d4-75a9-4190-9e51-f08a7b705c7d",                        [{"mode":"markers","text":["Afghanistan","Albania","Algeria","Angola","Argentina","Australia","Austria","Bahrain","Bangladesh","Belgium","Benin","Bolivia","Bosnia and Herzegovina","Botswana","Brazil","Bulgaria","Burkina Faso","Burundi","Cambodia","Cameroon","Canada","Central African Republic","Chad","Chile","China","Colombia","Comoros","Congo, Dem. Rep.","Congo, Rep.","Costa Rica","Cote d'Ivoire","Croatia","Cuba","Czech Republic","Denmark","Djibouti","Dominican Republic","Ecuador","Egypt","El Salvador","Equatorial Guinea","Eritrea","Ethiopia","Finland","France","Gabon","Gambia","Germany","Ghana","Greece","Guatemala","Guinea","Guinea-Bissau","Haiti","Honduras","Hong Kong, China","Hungary","Iceland","India","Indonesia","Iran","Iraq","Ireland","Israel","Italy","Jamaica","Japan","Jordan","Kenya","Korea, Dem. Rep.","Korea, Rep.","Kuwait","Lebanon","Lesotho","Liberia","Libya","Madagascar","Malawi","Malaysia","Mali","Mauritania","Mauritius","Mexico","Mongolia","Montenegro","Morocco","Mozambique","Myanmar","Namibia","Nepal","Netherlands","New Zealand","Nicaragua","Niger","Nigeria","Norway","Oman","Pakistan","Panama","Paraguay","Peru","Philippines","Poland","Portugal","Puerto Rico","Reunion","Romania","Rwanda","Sao Tome and Principe","Saudi Arabia","Senegal","Serbia","Sierra Leone","Singapore","Slovak Republic","Slovenia","Somalia","South Africa","Spain","Sri Lanka","Sudan","Swaziland","Sweden","Switzerland","Syria","Taiwan","Tanzania","Thailand","Togo","Trinidad and Tobago","Tunisia","Turkey","Uganda","United Kingdom","United States","Uruguay","Venezuela","Vietnam","West Bank and Gaza","Yemen, Rep.","Zambia","Zimbabwe"],"x":[779.4453145,1601.056136,2449.008185,3520.610273,5911.315053,10039.59564,6137.076492,9867.084765,684.2441716,8343.105127,1062.7522,2677.326347,973.5331948,851.2411407,2108.944355,2444.286648,543.2552413,339.2964587,368.4692856,1172.667655,11367.16112,1071.310713,1178.665927,3939.978789,400.448611,2144.115096,1102.990936,780.5423257,2125.621418,2627.009471,1388.594732,3119.23652,5586.53878,6876.14025,9692.385245,2669.529475,1397.717137,3522.110717,1418.822445,3048.3029,375.6431231,328.9405571,362.1462796,6424.519071,7029.809327,4293.476475,485.2306591,7144.114393,911.2989371,3530.690067,2428.237769,510.1964923,299.850319,1840.366939,2194.926204,3054.421209,5263.673816,7267.688428,546.5657493,749.6816546,3035.326002,4129.766056,5210.280328,4086.522128,4931.404155,2898.530881,3216.956347,1546.907807,853.540919,1088.277758,1030.592226,108382.3529,4834.804067,298.8462121,575.5729961,2387.54806,1443.011715,369.1650802,1831.132894,452.3369807,743.1159097,1967.955707,3478.125529,786.5668575,2647.585601,1688.20357,468.5260381,331.0,2423.780443,545.8657229,8941.571858,10556.57566,3112.363948,761.879376,1077.281856,10095.42172,1828.230307,684.5971438,2480.380334,1952.308701,3758.523437,1272.880995,4029.329699,3068.319867,3081.959785,2718.885295,3144.613186,493.3238752,879.5835855,6459.554823,1450.356983,3581.459448,879.7877358,2315.138227,5074.659104,4215.041741,1135.749842,4725.295531,3834.034742,1083.53203,1615.991129,1148.376626,8527.844662,14734.23275,1643.485354,1206.947913,716.6500721,757.7974177,859.8086567,3023.271928,1468.475631,1969.10098,734.753484,9979.508487,13990.48208,5716.766744,7689.799761,605.0664917,1515.592329,781.7175761,1147.388831,406.8841148],"y":[28.801,55.23,43.077,30.015,62.485,69.12,6 ...

# %% [markdown]
# We can also add pause and play buttons for the interactive chart.

# %% [markdown]
# ## Adding pause-play button <a name="button"></a>

# %%
figure['layout']['updatemenus'] = [
    {
        'buttons': [
            {
                'args': [None, {'frame': {'duration': 500, 'redraw': False},
                         'fromcurrent': True, 'transition': {'duration': 300, 
                                                             'easing': 'quadratic-in-out'}}],
                'label': 'Play',
                'method': 'animate'
            },
            {
                'args': [[None], {'frame': {'duration':0, 'redraw': False}, 'mode': 'immediate',
                'transition': {'duration': 0}}],
                'label': 'Pause',
                'method': 'animate'
            }
        ],
        'direction': 'left',
        'pad': {'r': 10, 't': 87},
        'showactive': False,
        'type': 'buttons',
        'x': 0.1,
        'xanchor': 'right',
        'y': 0,
        'yanchor': 'top'
    }
]

# Convert to plotly graph object and plot the figure
fig = go.Figure(figure)
fig.show(renderer="notebook_connected")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="9ac83c8a-2412-4155-a995-7f58cc768bb3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("9ac83c8a-2412-4155-a995-7f58cc768bb3")) {                    Plotly.newPlot(                        "9ac83c8a-2412-4155-a995-7f58cc768bb3",                        [{"mode":"markers","text":["Afghanistan","Albania","Algeria","Angola","Argentina","Australia","Austria","Bahrain","Bangladesh","Belgium","Benin","Bolivia","Bosnia and Herzegovina","Botswana","Brazil","Bulgaria","Burkina Faso","Burundi","Cambodia","Cameroon","Canada","Central African Republic","Chad","Chile","China","Colombia","Comoros","Congo, Dem. Rep.","Congo, Rep.","Costa Rica","Cote d'Ivoire","Croatia","Cuba","Czech Republic","Denmark","Djibouti","Dominican Republic","Ecuador","Egypt","El Salvador","Equatorial Guinea","Eritrea","Ethiopia","Finland","France","Gabon","Gambia","Germany","Ghana","Greece","Guatemala","Guinea","Guinea-Bissau","Haiti","Honduras","Hong Kong, China","Hungary","Iceland","India","Indonesia","Iran","Iraq","Ireland","Israel","Italy","Jamaica","Japan","Jordan","Kenya","Korea, Dem. Rep.","Korea, Rep.","Kuwait","Lebanon","Lesotho","Liberia","Libya","Madagascar","Malawi","Malaysia","Mali","Mauritania","Mauritius","Mexico","Mongolia","Montenegro","Morocco","Mozambique","Myanmar","Namibia","Nepal","Netherlands","New Zealand","Nicaragua","Niger","Nigeria","Norway","Oman","Pakistan","Panama","Paraguay","Peru","Philippines","Poland","Portugal","Puerto Rico","Reunion","Romania","Rwanda","Sao Tome and Principe","Saudi Arabia","Senegal","Serbia","Sierra Leone","Singapore","Slovak Republic","Slovenia","Somalia","South Africa","Spain","Sri Lanka","Sudan","Swaziland","Sweden","Switzerland","Syria","Taiwan","Tanzania","Thailand","Togo","Trinidad and Tobago","Tunisia","Turkey","Uganda","United Kingdom","United States","Uruguay","Venezuela","Vietnam","West Bank and Gaza","Yemen, Rep.","Zambia","Zimbabwe"],"x":[779.4453145,1601.056136,2449.008185,3520.610273,5911.315053,10039.59564,6137.076492,9867.084765,684.2441716,8343.105127,1062.7522,2677.326347,973.5331948,851.2411407,2108.944355,2444.286648,543.2552413,339.2964587,368.4692856,1172.667655,11367.16112,1071.310713,1178.665927,3939.978789,400.448611,2144.115096,1102.990936,780.5423257,2125.621418,2627.009471,1388.594732,3119.23652,5586.53878,6876.14025,9692.385245,2669.529475,1397.717137,3522.110717,1418.822445,3048.3029,375.6431231,328.9405571,362.1462796,6424.519071,7029.809327,4293.476475,485.2306591,7144.114393,911.2989371,3530.690067,2428.237769,510.1964923,299.850319,1840.366939,2194.926204,3054.421209,5263.673816,7267.688428,546.5657493,749.6816546,3035.326002,4129.766056,5210.280328,4086.522128,4931.404155,2898.530881,3216.956347,1546.907807,853.540919,1088.277758,1030.592226,108382.3529,4834.804067,298.8462121,575.5729961,2387.54806,1443.011715,369.1650802,1831.132894,452.3369807,743.1159097,1967.955707,3478.125529,786.5668575,2647.585601,1688.20357,468.5260381,331.0,2423.780443,545.8657229,8941.571858,10556.57566,3112.363948,761.879376,1077.281856,10095.42172,1828.230307,684.5971438,2480.380334,1952.308701,3758.523437,1272.880995,4029.329699,3068.319867,3081.959785,2718.885295,3144.613186,493.3238752,879.5835855,6459.554823,1450.356983,3581.459448,879.7877358,2315.138227,5074.659104,4215.041741,1135.749842,4725.295531,3834.034742,1083.53203,1615.991129,1148.376626,8527.844662,14734.23275,1643.485354,1206.947913,716.6500721,757.7974177,859.8086567,3023.271928,1468.475631,1969.10098,734.753484,9979.508487,13990.48208,5716.766744,7689.799761,605.0664917,1515.592329,781.7175761,1147.388831,406.8841148],"y":[28.801,55.23,43.077,30.015,62.485,69.12,6 ...

# %% [markdown]
# ## Using bubble size as a variable <a name="size"></a>

# %% [markdown]
# Now we build on the above interactive graph by setting the size of the bubble as another variable viz. population. Since, there will be repetition of the code illustrated above, this time we have simply used the functions  `make_grid`, `set_layout` and `get_trace` imported from the module  [`bubbly`](https://github.com/AashitaK/bubbly).

# %%
# Create local functions to replace bubbly dependencies
def make_grid_local(dataset, column_names, time_column, years):
    grid_rows = []
    col_name_template = '{}+{}_grid'
    for year in years:
        dataset_by_year = dataset[(dataset[time_column] == int(year))]
        for col_name in column_names:
            temp = col_name_template.format(year, col_name)
            if dataset_by_year[col_name].size != 0:
                grid_rows.append({'value': list(dataset_by_year[col_name]), 'key': temp})
    return pd.DataFrame(grid_rows)

def set_layout_local(x_title, y_title, title, x_logscale, y_logscale, show_slider, slider_scale, show_button, show_legend, height):
    figure = {'data': [], 'layout': {}, 'frames': []}
    figure['layout'] = {
        'xaxis': {'title': x_title, 'type': 'log' if x_logscale else 'linear'},
        'yaxis': {'title': y_title},
        'title': title,
        'showlegend': show_legend,
        'hovermode': 'closest',
        'height': height
    }
    sliders_dict = {
        'active': 0,
        'yanchor': 'top',
        'xanchor': 'left',
        'currentvalue': {'font': {'size': 20}, 'prefix': 'Year:', 'visible': True, 'xanchor': 'right'},
        'transition': {'duration': 300, 'easing': 'cubic-in-out'},
        'pad': {'b': 10, 't': 50},
        'len': 0.9, 'x': 0.1, 'y': 0,
        'steps': []
    }
    return figure, sliders_dict

def get_trace_local(grid, col_name_template_year, x_column, y_column, bubble_column, size_column):
    trace = {
        'x': grid.loc[grid['key']==col_name_template_year.format(x_column), 'value'].values[0],
        'y': grid.loc[grid['key']==col_name_template_year.format(y_column), 'value'].values[0],
        'mode': 'markers',
        'text': grid.loc[grid['key']==col_name_template_year.format(bubble_column), 'value'].values[0],
        'marker': {'size': grid.loc[grid['key']==col_name_template_year.format(size_column), 'value'].values[0]},
        'type': 'scatter'
    }
    return trace

# Define the new variable
size_column = 'pop' 

# Make the grid
years = dataset[time_column].unique()
col_name_template = '{}+{}_grid'
column_names = [x_column, y_column, bubble_column, size_column]
grid = make_grid_local(dataset, column_names, time_column, years)
    
# Set the layout
figure, sliders_dict = set_layout_local(x_title='GDP per Capita', y_title='Life Expectancy', 
            title='Gapminder Global Indicators', x_logscale=True, y_logscale=False, 
            show_slider=True, slider_scale=years, show_button=True, show_legend=False, 
            height=650)

# Add the base frame
year = min(years)
col_name_template_year = col_name_template.format(year, '{}')
trace = get_trace_local(grid=grid, col_name_template_year=col_name_template_year, 
                    x_column=x_column, y_column=y_column, 
                    bubble_column=bubble_column, size_column=size_column)
figure['data'].append(trace)


# Add time frames
for year in years:
    frame = {'data': [], 'name': str(year)}
    col_name_template_year = col_name_template.format(year, '{}')
    trace = get_trace_local(grid=grid, col_name_template_year=col_name_template_year, 
                    x_column=x_column, y_column=y_column, 
                    bubble_column=bubble_column, size_column=size_column)
    frame['data'].append(trace)
    figure['frames'].append(frame) 
    add_slider_steps(sliders_dict, year)

# Set the layout once more
figure['layout']['xaxis']['autorange'] = True
figure['layout']['yaxis']['range'] = [20, 100]
figure['layout']['sliders'] = [sliders_dict]

# Convert to plotly graph object and plot the animation
fig = go.Figure(figure)
fig.show(renderer="notebook_connected")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="db873d5d-572e-40e3-8012-bbbf899e7988" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("db873d5d-572e-40e3-8012-bbbf899e7988")) {                    Plotly.newPlot(                        "db873d5d-572e-40e3-8012-bbbf899e7988",                        [{"marker":{"size":[8425333,1282697,9279525,4232095,17876956,8691212,6927772,120447,46886859,8730405,1738315,2883315,2791000,442308,56602560,7274900,4469979,2445618,4693836,5009067,14785584,1291695,2682462,6377619,556263527,12350771,153936,14100005,854885,926317,2977019,3882229,6007797,9125183,4334000,63149,2491346,3548753,22223309,2042865,216964,1438760,20860941,4090500,42459667,420702,284320,69145952,5581001,7733250,3146381,2664249,580653,3201488,1517453,2125900,9504000,147962,372000000,82052000,17272000,5441766,2952156,1620914,47666000,1426095,86459025,607914,6464046,8865488,20947571,160000,1439529,748747,863308,1019729,4762912,2917802,6748378,3838168,1022556,516556,30144317,800663,413834,9939217,6446316,20092996,485831,9182536,10381988,1994794,1165790,3379468,33119096,3327728,507833,41346560,940080,1555876,8025700,22438691,25730551,8526050,2227000,257700,16630000,2534927,60011,4005677,2755589,6860147,2143249,1127000,3558137,1489518,2526994,14264935,28549870,7982342,8504667,290243,7124673,4815000,3661549,8550362,8322925,21289402,1219113,662850,3647735,22235677,5824797,50430000,157553000,2252965,5439568,26246839,1030585,4963829,2672000,3080907]},"mode":"markers","text":["Afghanistan","Albania","Algeria","Angola","Argentina","Australia","Austria","Bahrain","Bangladesh","Belgium","Benin","Bolivia","Bosnia and Herzegovina","Botswana","Brazil","Bulgaria","Burkina Faso","Burundi","Cambodia","Cameroon","Canada","Central African Republic","Chad","Chile","China","Colombia","Comoros","Congo, Dem. Rep.","Congo, Rep.","Costa Rica","Cote d'Ivoire","Croatia","Cuba","Czech Republic","Denmark","Djibouti","Dominican Republic","Ecuador","Egypt","El Salvador","Equatorial Guinea","Eritrea","Ethiopia","Finland","France","Gabon","Gambia","Germany","Ghana","Greece","Guatemala","Guinea","Guinea-Bissau","Haiti","Honduras","Hong Kong, China","Hungary","Iceland","India","Indonesia","Iran","Iraq","Ireland","Israel","Italy","Jamaica","Japan","Jordan","Kenya","Korea, Dem. Rep.","Korea, Rep.","Kuwait","Lebanon","Lesotho","Liberia","Libya","Madagascar","Malawi","Malaysia","Mali","Mauritania","Mauritius","Mexico","Mongolia","Montenegro","Morocco","Mozambique","Myanmar","Namibia","Nepal","Netherlands","New Zealand","Nicaragua","Niger","Nigeria","Norway","Oman","Pakistan","Panama","Paraguay","Peru","Philippines","Poland","Portugal","Puerto Rico","Reunion","Romania","Rwanda","Sao Tome and Principe","Saudi Arabia","Senegal","Serbia","Sierra Leone","Singapore","Slovak Republic","Slovenia","Somalia","South Africa","Spain","Sri Lanka","Sudan","Swaziland","Sweden","Switzerland","Syria","Taiwan","Tanzania","Thailand","Togo","Trinidad and Tobago","Tunisia","Turkey","Uganda","United Kingdom","United States","Uruguay","Venezuela","Vietnam","West Bank and Gaza","Yemen, Rep.","Zambia","Zimbabwe"],"x":[779.4453145,1601.056136,2449.008185,3520.610273,5911.315053,10039.59564,6137.076492,9867.084765,684.2441716,8343.105127,1062.7522,2677.326347,973.5331948,851.2411407,2108.944355,2444.286648,543.2552413,339.2964587,368.4692856,1172.667655,11367.16112,1071.310713,1178.665927,3939.978789,400.448611,2144.115096,1102.990936,780.5423257,2125.621418,2627.009471,1388.594732,3119.23652,5586.53878,6876.14025,9692.385245,2669.529475,1397.717137,3522.110717,1418.822445,3048.3029,375.6431231,328.9405571,362.1462796,6424.519071,7029.809327,4293.476475,485.2306591,7144.1143 ...

# %% [markdown]
# ## Using colors to classify into categories <a name="color"></a>

# %% [markdown]
# Now, a category variable, namely continent in our case, is added. For making the grid, we will have an additional `for` loop for continents. Since the function is still not that different from the code above, we have used the function `make_grid_with_categories` imported from the module  [`bubbly`](https://github.com/AashitaK/bubbly) instead of lengthening the code block. Similarly, there is an additional `for` loop for continents while adding data to time frames as well. The rest of the process is similar to that of above, except that the function `make_data_dictionary` is passed an additional argument, namely `continent`.

# %%
# Create local function to replace make_grid_with_categories
def make_grid_with_categories_local(dataset, column_names, time_column, category_column, years, categories):
    grid_rows = []
    col_name_template = '{}+{}+{}_grid'
    for year in years:
        for category in categories:
            dataset_by_year_and_cat = dataset[(dataset[time_column] == int(year)) & (dataset[category_column] == category)]
            for col_name in column_names:
                temp = col_name_template.format(year, col_name, category)
                if dataset_by_year_and_cat[col_name].size != 0:
                    grid_rows.append({'value': list(dataset_by_year_and_cat[col_name]), 'key': temp})
    return pd.DataFrame(grid_rows)

def get_trace_with_category_local(grid, col_name_template_year, x_column, y_column, bubble_column, size_column, category):
    try:
        trace = {
            'x': grid.loc[grid['key']==col_name_template_year.format(x_column, category), 'value'].values[0],
            'y': grid.loc[grid['key']==col_name_template_year.format(y_column, category), 'value'].values[0],
            'mode': 'markers',
            'text': grid.loc[grid['key']==col_name_template_year.format(bubble_column, category), 'value'].values[0],
            'marker': {'size': grid.loc[grid['key']==col_name_template_year.format(size_column, category), 'value'].values[0]},
            'name': category,
            'type': 'scatter'
        }
        return trace
    except:
        return None

# Define the new variable
category_column = 'continent'

# Make the grid
years = dataset[time_column].unique()
continents = dataset[category_column].unique()
col_name_template = '{}+{}+{}_grid'
column_names = [x_column, y_column, bubble_column, size_column]
grid = make_grid_with_categories_local(dataset, column_names, time_column, 
                                 category_column, years, continents)
    
# Set the layout
figure, sliders_dict = set_layout_local(x_title='GDP per Capita', y_title='Life Expectancy', 
            title='Gapminder Global Indicators', x_logscale=True, y_logscale=False, 
            show_slider=True, slider_scale=years, show_button=True, show_legend=False, height=650)

# Add the base frame
year = min(years)
col_name_template_year = col_name_template.format(year, '{}', '{}')
for continent in continents:
    trace = get_trace_with_category_local(grid=grid, col_name_template_year=col_name_template_year, 
                    x_column=x_column, y_column=y_column, 
                    bubble_column=bubble_column, size_column=size_column, category=continent)
    if trace:
        figure['data'].append(trace)

# Add time frames
for year in years:
    frame = {'data': [], 'name': str(year)}
    col_name_template_year = col_name_template.format(year, '{}', '{}')
    for continent in continents:
        trace = get_trace_with_category_local(grid=grid, col_name_template_year=col_name_template_year, 
                    x_column=x_column, y_column=y_column, 
                    bubble_column=bubble_column, size_column=size_column, category=continent)
        if trace:
            frame['data'].append(trace)

    figure['frames'].append(frame) 
    add_slider_steps(sliders_dict, year)

# Set the layout once more
figure['layout']['xaxis']['autorange'] = True
figure['layout']['yaxis']['range'] = [20, 100]
figure['layout']['showlegend'] = True
figure['layout']['sliders'] = [sliders_dict]

# Convert to plotly graph object and plot the animation
fig = go.Figure(figure)
fig.show(renderer="notebook_connected")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="78f0d14a-756d-4d44-b5c1-07a2e636e9b6" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("78f0d14a-756d-4d44-b5c1-07a2e636e9b6")) {                    Plotly.newPlot(                        "78f0d14a-756d-4d44-b5c1-07a2e636e9b6",                        [{"marker":{"size":[8425333,120447,46886859,4693836,556263527,2125900,372000000,82052000,17272000,5441766,1620914,86459025,607914,8865488,20947571,160000,1439529,6748378,800663,20092996,9182536,507833,41346560,22438691,4005677,1127000,7982342,3661549,8550362,21289402,26246839,1030585,4963829]},"mode":"markers","name":"Asia","text":["Afghanistan","Bahrain","Bangladesh","Cambodia","China","Hong Kong, China","India","Indonesia","Iran","Iraq","Israel","Japan","Jordan","Korea, Dem. Rep.","Korea, Rep.","Kuwait","Lebanon","Malaysia","Mongolia","Myanmar","Nepal","Oman","Pakistan","Philippines","Saudi Arabia","Singapore","Sri Lanka","Syria","Taiwan","Thailand","Vietnam","West Bank and Gaza","Yemen, Rep."],"x":[779.4453145,9867.084765,684.2441716,368.4692856,400.448611,3054.421209,546.5657493,749.6816546,3035.326002,4129.766056,4086.522128,3216.956347,1546.907807,1088.277758,1030.592226,108382.3529,4834.804067,1831.132894,786.5668575,331.0,545.8657229,1828.230307,684.5971438,1272.880995,6459.554823,2315.138227,1083.53203,1643.485354,1206.947913,757.7974177,605.0664917,1515.592329,781.7175761],"y":[28.801,50.939,37.484,39.417,44.0,60.96,37.373,37.468,44.869,45.32,65.39,63.03,43.158,50.056,47.453,55.565,55.928,48.463,42.244,36.319,36.157,37.578,43.436,47.752,39.875,60.396,57.593,45.883,58.5,50.848,40.412,43.16,32.548],"type":"scatter"},{"marker":{"size":[1282697,6927772,8730405,2791000,7274900,3882229,9125183,4334000,4090500,42459667,69145952,7733250,9504000,147962,2952156,47666000,413834,10381988,3327728,25730551,8526050,16630000,6860147,3558137,1489518,28549870,7124673,4815000,22235677,50430000]},"mode":"markers","name":"Europe","text":["Albania","Austria","Belgium","Bosnia and Herzegovina","Bulgaria","Croatia","Czech Republic","Denmark","Finland","France","Germany","Greece","Hungary","Iceland","Ireland","Italy","Montenegro","Netherlands","Norway","Poland","Portugal","Romania","Serbia","Slovak Republic","Slovenia","Spain","Sweden","Switzerland","Turkey","United Kingdom"],"x":[1601.056136,6137.076492,8343.105127,973.5331948,2444.286648,3119.23652,6876.14025,9692.385245,6424.519071,7029.809327,7144.114393,3530.690067,5263.673816,7267.688428,5210.280328,4931.404155,2647.585601,8941.571858,10095.42172,4029.329699,3068.319867,3144.613186,3581.459448,5074.659104,4215.041741,3834.034742,8527.844662,14734.23275,1969.10098,9979.508487],"y":[55.23,66.8,68.0,53.82,59.6,61.21,66.87,70.78,66.55,67.41,67.5,65.86,64.03,72.49,66.91,65.94,59.164,72.13,72.67,61.31,59.82,61.05,57.996,64.36,65.57,64.94,71.86,69.62,43.585,69.18],"type":"scatter"},{"marker":{"size":[9279525,4232095,1738315,442308,4469979,2445618,5009067,1291695,2682462,153936,14100005,854885,2977019,63149,22223309,216964,1438760,20860941,420702,284320,5581001,2664249,580653,6464046,748747,863308,1019729,4762912,2917802,3838168,1022556,516556,9939217,6446316,485831,3379468,33119096,257700,2534927,60011,2755589,2143249,2526994,14264935,8504667,290243,8322925,1219113,3647735,5824797,2672000,3080907]},"mode":"markers","name":"Africa","text":["Algeria","Angola","Benin","Botswana","Burkina Faso","Burundi","Cameroon","Central African Republic","Chad","Comoros","Congo, Dem. Rep.","Congo, Rep.","Cote d'Ivoire","Djibouti","Egypt","Equatorial Guinea","Eritrea","Ethiopia","Gabon","Gambia","Ghana","Guinea","Guinea-Bissau","Kenya","Lesotho","Liberia","Libya","Madagascar","Malawi","Mali","Mau ...

# %% [markdown]
# So, we have finally generated the same interactive graph as the one generated above using the function `bubbleplot`.

# %% [markdown]
# ### References:
# * https://plot.ly/python/animations/
# * https://stackoverflow.com/questions/45780920/plotly-icreate-animations-offline-on-jupyter-notebook
# * https://plot.ly/python/gapminder-example/
#
# ### More kernels illustrating the use of `bubbly`:
# * https://www.kaggle.com/gpreda/meta-kaggle-what-happened-to-the-team-size
# * https://www.kaggle.com/gpreda/earthquakes-animation-using-bubbly

# %% [markdown]
# All questions, comments and/or suggestions for improvement of the module  [`bubbly`](https://github.com/AashitaK/bubbly) are most welcome!
#
# ***Update: I am looking for a Maintainer for this [python package](https://pypi.org/project/bubbly/). There are some open requests and issues to fix that I am not able to address in a timely manner because of other work commitments. If you are interested, please reach out. My contact information is given in my Kaggle profile.***
